# %% [markdown]
# <a href="https://colab.research.google.com/github/quevedooo/PROGCOM_B_2026/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##IF/ELSE
# Se usa cunado una condición solo puede dar dos valores de verdad: Verdadero y falso
# Sintaxis en python
#
# ```
# if (condición):
#  Aquí se ejecuta código si la condición es verdader
# else:
#  Aquí se ejecuta código si la ejecución es falsa
# ```
# Sintaxis en java
# ```
# if (condición){
#    Aquí se ejecuta código si la condición es verdadera
# }else{
#    Aquí se ejecuta código si la condición es falsa
# }
# ```

# %%
edad=int(input("Cual es tu edad?"))
if edad>= 18:
  print("Usted es mayor de edad")
else:
  print("Usted es menor de edad")
# Out:
# Cual es tu edad?17
# Usted es menor de edad

# %%
if edad<10: print("Aún eres un niño")
else:
  if edad>=10 and edad<14: print("Eres un preadolescente")
  else:
    if edad>=14 and edad<18: print("Eres un adolescente")
    else:
      if edad>=18 and edad<30: print("Eres un adulto joven")
      else: print("Eres un adulto")
# Out:
# Eres un adolescente

# %%
if edad<10: print("Aun eres un adulto")
elif edad=>10 and edad<14: print8"
