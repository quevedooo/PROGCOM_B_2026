# %% [markdown]
# <a href="https://colab.research.google.com/github/quevedooo/PROGCOM_B_2026/blob/main/Diccionarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Diccionarios
# 1. Tipo de dato
# 2. **NO TIENEN INDEX**. Tienen
# clave: Valor
# 3. Las claves **SIEMPRE** son caracteres.
# 4. Los valores pueden ser cualquier otro tipo de dato
#
# Sintaxis
# ```
# variable={"clave1":valor, "clave2": valor,...,"clave":valor}*texto en cursiva*
# ```

# %%
galleta=["dinosaurio", "flores", "carro"]
precio=[5000,6000,7000]
cant=[5,5,6]

# %%
def menu():
 for galletas in range(3):
  print (f"{galleta[galletas]}, precio={precio[galletas]}, cantidad={cant[galletas]}")

# %%
menu()
# Out:
# dinosaurio, precio=5000, cantidad=5
# flores, precio=6000, cantidad=5
# carro, precio=7000, cantidad=6

# %%
para_vender={"galleta":["dinosaurio", "flores", "carro"],
             "precio":[5000,6000,7000],
             "cant":[5,5,6]}

# %%
type(para_vender)
# Out:
# dict

# %%
type(galleta)
# Out:
# list

# %% [markdown]
# Navegando en un *diccionario*

# %%
print(para_vender)
# Out:
# {'galleta': ['dinosaurio', 'flores', 'carro'], 'precio': [5000, 6000, 7000], 'cant': [5, 5, 6]}

# %%
para_vender["galleta"]
# Out:
# ['dinosaurio', 'flores', 'carro']

# %%
para_vender["galleta"][1]
# Out:
# 'flores'

# %%
para_vender["precio"][1:3]
# Out:
# [6000, 7000]
