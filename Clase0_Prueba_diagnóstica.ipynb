# %% [markdown]
# ##Título de nivel 1
# ##Título de nivel 2
# ###Título de nivel 3
#
# hola,cómo estas?🤣
# 1. hola
# 2. cómo
# 3. estás

# %% [markdown]
# ##INPUT
# Input es una función, que permite ongresar datos.
#
# Posee tres funciones
# 1. Lee: Se puede ingresar información
# 2. Almacena: Guarda la información
# 3. Declara: Todos los datos los vuelve string.
#
# Sintaxis
# ```
# var=input(Aquí va su impresión)
# ```
# Si se desea realizar una lectura de un tipo de dato diferente a string, se debe realizar una conversión de datos.
# Para ello, coloque el tipo de dato que desea convertir, y enccierre el tipo original de dato entre paréntesis.
#
# ```
# var=int(input()) #Aquí se va a transformar un dato de string a entero
# var2=float(input()) #Se transforma de string a decimal
# var3=bool(input()) #Se transforma de string a booleano
# ```

# %%
print("Hola mundo😎")
# Out:
# Hola mundo😎

# %%
nombre=input("Cómo te llamas?")

# %%
edad=int(input("Cuantos años tienes?"))
# Out:
# Cuantos años tienes?20
# edad

# %%
edad_compañero_derecha=int(input("Hola compañero, cuantos años tienes?"))

# %%
print(f"La suma de las dos edades es {edad+edad_compañero_derecha}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1291342035.py in <cell line: 0>()
# ----> 1 print(f"La suma de las dos edades es {edad+edad_compañero_derecha}")
#
# NameError: name 'edad_compañero_derecha' is not defined
